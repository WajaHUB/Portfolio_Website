# %%
import pandas as pd

# Specify the path to your CSV file including the file name
file_path = r'C:\Users\jackf\OneDrive\Desktop\Bike_Sharing\UCI_Bike_Sharing\data\day.csv'

# Read the CSV file into a DataFrame
day_Bike = pd.read_csv(file_path)

# Display the DataFrame
day_Bike
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0          1  2011-01-01       1   0     1        0        6           0
# 1          2  2011-01-02       1   0     1        0        0           0
# 2          3  2011-01-03       1   0     1        0        1           1
# 3          4  2011-01-04       1   0     1        0        2           1
# 4          5  2011-01-05       1   0     1        0        3           1
# ..       ...         ...     ...  ..   ...      ...      ...         ...
# 726      727  2012-12-27       1   1    12        0        4           1
# 727      728  2012-12-28       1   1    12        0        5           1
# 728      729  2012-12-29       1   1    12        0        6           0
# 729      730  2012-12-30       1   1    12        0        0           0
# 730      731  2012-12-31       1   1    12        0        1           1
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# ...

# %%
import pandas as pd
import statsmodels.api as sm
from statsmodels.tsa.arima.model import ARIMA

# Assuming your date_Bike dataframe has a datetime index
day_Bike['dteday'] = pd.to_datetime(day_Bike['dteday'])
day_Bike.set_index('dteday', inplace=True)

# Replace 'your_column' with the column you want to predict (e.g., 'cnt')
y = day_Bike['cnt']

# Fit ARIMA model
arima_model = ARIMA(y, order = (5, 1, 0))  # Example order, you may need to tune this
arima_result = arima_model.fit()

# Forecast future values
future_steps = 30  # Adjust as needed
forecast = arima_result.get_forecast(steps = future_steps)

# Print the forecasted values
forecast.predicted_mean
# Out:
# C:\Users\jackf\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\jackf\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\jackf\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# 2013-01-01    2085.026056
# 2013-01-02    2174.025046
# 2013-01-03    2289.020528
# 2013-01-04    2057.877658
# 2013-01-05    2087.776140
# 2013-01-06    2231.349366
# 2013-01-07    2179.724878
# 2013-01-08    2180.821824
# 2013-01-09    2189.451815
# 2013-01-10    2154.891201
# 2013-01-11    2153.154758
# 2013-01-12    2174.959020
# 2013-01-13    2174.545152
# ...

# %%
import pandas as pd
import statsmodels.api as sm
from statsmodels.tsa.arima.model import ARIMA

# Assuming your date_Bike dataframe has a datetime index
day_Bike['dteday'] = pd.to_datetime(day_Bike['dteday'])
day_Bike.set_index('dteday', inplace=True)

# Replace 'your_column' with the column you want to predict (e.g., 'cnt')
y = day_Bike['cnt']

# Fit ARIMA model
arima_model = ARIMA(y, order=(5, 1, 0))  # Example order, you may need to tune this
arima_result = arima_model.fit()

# Forecast future values for the year 2100
future_steps = 365 * (2100 - 2013)  # Assuming a daily frequency
future_dates = pd.date_range(start='2013-01-01', periods=future_steps)
forecast = arima_result.get_forecast(steps=future_steps)

# Create a new DataFrame for the forecasted values
forecast_df = pd.DataFrame(forecast.predicted_mean, index=future_dates, columns=['predicted_mean'])

# Print or use the forecasted values
forecast_df
# Out:
# C:\Users\jackf\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\jackf\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\jackf\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
#             predicted_mean
# 2013-01-01     2085.026056
# 2013-01-02     2174.025046
# 2013-01-03     2289.020528
# 2013-01-04     2057.877658
# 2013-01-05     2087.776140
# ...                    ...
# 2099-12-06     2171.052334
# 2099-12-07     2171.052334
# 2099-12-08     2171.052334
# 2099-12-09     2171.052334
# 2099-12-10     2171.052334
#
# ...

# %%
import pandas as pd
import statsmodels.api as sm
from statsmodels.tsa.arima.model import ARIMA

# Assuming your date_Bike dataframe has a datetime index
day_Bike['dteday'] = pd.to_datetime(day_Bike['dteday'])
day_Bike.set_index('dteday', inplace=True)

# Replace 'your_column' with the column you want to predict (e.g., 'cnt')
y = day_Bike['cnt']

# Fit ARIMA model
arima_model = ARIMA(y, order=(5, 1, 0))  # Example order, you may need to tune this
arima_result = arima_model.fit()

# Forecast future values for the year 2100
future_steps = 365 * (2100 - 2013)  # Assuming a daily frequency
future_dates = pd.date_range(start='2013-01-01', periods=future_steps)
forecast = arima_result.get_forecast(steps=future_steps)

# Add forecasted values to a new DataFrame
forecast_df = pd.DataFrame(index=future_dates)
forecast_df['predicted_mean'] = forecast.predicted_mean

# Access the forecasted value for January 5, 2100
specific_date = pd.to_datetime('2099-01-05')
forecast_value = forecast_df.loc[specific_date, 'predicted_mean']

# Print or use the forecasted value
print(f'Predicted value for 2100-01-05: {forecast_value:.2f}')
# Out:
# C:\Users\jackf\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\jackf\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\jackf\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# Predicted value for 2100-01-05: 2171.05

# %%
# Assuming 'day_Bike_actual' is a DataFrame with actual values for the forecast period
day_Bike_actual['dteday'] = pd.to_datetime(day_Bike_actual['dteday'])
day_Bike_actual.set_index('dteday', inplace=True)

# Extract the actual values for the forecast period
y_true = day_Bike_actual['cnt']

# Forecast future values
future_steps = 30  # Adjust as needed
forecast = arima_result.get_forecast(steps=future_steps)

# Align indices using forecast.predicted_mean.index
y_true = y_true.loc[forecast.predicted_mean.index]

# Compute metrics
mae = mean_absolute_error(y_true, forecast.predicted_mean)
mse = mean_squared_error(y_true, forecast.predicted_mean)
rmse = np.sqrt(mse)

print(f'Mean Absolute Error (MAE): {mae}')
print(f'Mean Squared Error (MSE): {mse}')
print(f'Root Mean Squared Error (RMSE): {rmse}')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[38], line 13
#      10 forecast = arima_result.get_forecast(steps=future_steps)
#      12 # Align indices using forecast.index
# ---> 13 y_true = y_true.loc[forecast.index]
#      15 # Compute metrics
#      16 mae = mean_absolute_error(y_true, forecast.predicted_mean)
#
# File ~\anaconda3\Lib\site-packages\statsmodels\base\wrapper.py:34, in ResultsWrapper.__getattribute__(self, attr)
#      31 except AttributeError:
#      32     pass
# ---> 34 obj = getattr(results, attr)
#      35 data = results.model.data
#      36 how = self._wrap_attrs.get(attr)
#
# AttributeError: 'PredictionResults' object has no attribute 'index'

# %%
# Assuming you have actual values for the same period
actual_values = day_Bike.loc['2013-01-01':'2100-01-01', 'cnt']

# Calculate the residuals (the differences between actual and predicted values)
residuals = actual_values - forecast_df['predicted_mean']

# Calculate Mean Absolute Error (MAE)
mae = abs(residuals).mean()
print(f'MAE: {mae:.2f}')

# Calculate Mean Squared Error (MSE)
mse = (residuals**2).mean()
print(f'MSE: {mse:.2f}')

# Calculate Root Mean Squared Error (RMSE)
rmse = mse**0.5
print(f'RMSE: {rmse:.2f}')
# Out:
# MAE: nan
# MSE: nan
# RMSE: nan

# %%
import pandas as pd

# Specify the path to your CSV file including the file name
file_path = r'C:\Users\jackf\OneDrive\Desktop\Bike_Sharing\UCI_Bike_Sharing\data\day.csv'

# Read the CSV file into a DataFrame
day_Bike = pd.read_csv(file_path)

# Remove the last 10 rows using iloc and create a new DataFrame
day_Bike_without_last_10 = day_Bike.iloc[:-10]

# Display the new DataFrame without the last 10 rows

(day_Bike_without_last_10)
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0          1  2011-01-01       1   0     1        0        6           0
# 1          2  2011-01-02       1   0     1        0        0           0
# 2          3  2011-01-03       1   0     1        0        1           1
# 3          4  2011-01-04       1   0     1        0        2           1
# 4          5  2011-01-05       1   0     1        0        3           1
# ..       ...         ...     ...  ..   ...      ...      ...         ...
# 716      717  2012-12-17       4   1    12        0        1           1
# 717      718  2012-12-18       4   1    12        0        2           1
# 718      719  2012-12-19       4   1    12        0        3           1
# 719      720  2012-12-20       4   1    12        0        4           1
# 720      721  2012-12-21       1   1    12        0        5           1
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# ...

# %%
import pandas as pd
import statsmodels.api as sm
from statsmodels.tsa.arima.model import ARIMA

# Assuming your date_Bike dataframe has a datetime index
day_Bike_without_last_10['dteday'] = pd.to_datetime(day_Bike['dteday'])
day_Bike_without_last_10.set_index('dteday', inplace=True)

# Replace 'your_column' with the column you want to predict (e.g., 'cnt')
y = day_Bike['cnt']

# Fit ARIMA model
arima_model = ARIMA(y, order = (5, 1, 0))  # Example order, you may need to tune this
arima_result = arima_model.fit()

# Forecast future values
future_steps = 10  # Adjust as needed
forecast = arima_result.get_forecast(steps = future_steps)

# Print the forecasted values
forecast.predicted_mean
# Out:
# C:\Users\jackf\AppData\Local\Temp\ipykernel_23096\634862653.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_Bike_without_last_10['dteday'] = pd.to_datetime(day_Bike['dteday'])
# 731    2085.026056
# 732    2174.025046
# 733    2289.020528
# 734    2057.877658
# 735    2087.776140
# 736    2231.349366
# 737    2179.724878
# 738    2180.821824
# 739    2189.451815
# 740    2154.891201
# Name: predicted_mean, dtype: float64

# %%
day_Bike
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0          1  2011-01-01       1   0     1        0        6           0
# 1          2  2011-01-02       1   0     1        0        0           0
# 2          3  2011-01-03       1   0     1        0        1           1
# 3          4  2011-01-04       1   0     1        0        2           1
# 4          5  2011-01-05       1   0     1        0        3           1
# ..       ...         ...     ...  ..   ...      ...      ...         ...
# 726      727  2012-12-27       1   1    12        0        4           1
# 727      728  2012-12-28       1   1    12        0        5           1
# 728      729  2012-12-29       1   1    12        0        6           0
# 729      730  2012-12-30       1   1    12        0        0           0
# 730      731  2012-12-31       1   1    12        0        1           1
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# ...

# %%
import pandas as pd

# Assuming your DataFrame is named day_Bike
# Replace this with your actual DataFrame name

# Load your DataFrame (replace this with your actual data loading code)
# Example: day_Bike = pd.read_csv('your_data.csv')

# Get the last 10 values from the "cnt" column
last_10_values = day_Bike['cnt'].tail(10)

# Print or use the values as needed
print(last_10_values)
# Out:
# 721    1749
# 722    1787
# 723     920
# 724    1013
# 725     441
# 726    2114
# 727    3095
# 728    1341
# 729    1796
# 730    2729
# Name: cnt, dtype: int64

# %%
forecast.predicted_mean
# Out:
# 2011-01-16    928.211561
# Freq: D, dtype: float64

# %%
import pandas as pd
import statsmodels.api as sm
from statsmodels.tsa.arima.model import ARIMA
import matplotlib.pyplot as plt

# Assuming your DataFrame is named day_Bike
# Make sure 'dteday' is already in datetime format in your original DataFrame

# Copy the DataFrame and exclude the last 10 rows
day_Bike_without_last_10 = day_Bike.iloc[:-10].copy()

# Replace 'your_column' with the column you want to predict (e.g., 'cnt')
y = day_Bike_without_last_10['cnt']

# Fit ARIMA model
arima_model = ARIMA(y, order=(5, 1, 0))  # Example order, you may need to tune this
arima_result = arima_model.fit()

# Forecast future values
future_steps = 10  # Adjust as needed
forecast = arima_result.get_forecast(steps=future_steps)

# Plotting
plt.figure(figsize=(12, 6))

# Plot actual values
plt.plot(day_Bike_without_last_10.index, day_Bike_without_last_10['cnt'], label='Actual', color='blue')

# Plot predicted values
plt.plot(forecast.predicted_mean.index, forecast.predicted_mean.values, label='ARIMA Prediction', color='red')

# Customize the plot
plt.title('Actual vs ARIMA Prediction')
plt.xlabel('Date')
plt.ylabel('Count')
plt.legend()
plt.grid(True)
plt.show()

# %%
import pandas as pd
import statsmodels.api as sm
from statsmodels.tsa.arima.model import ARIMA
import matplotlib.pyplot as plt

# Assuming your DataFrame is named day_Bike
# Make sure 'dteday' is already in datetime format in your original DataFrame

# Copy the DataFrame and exclude the last 10 rows
day_Bike_without_last_10 = day_Bike.iloc[:-10].copy()

# Replace 'your_column' with the column you want to predict (e.g., 'cnt')
y = day_Bike_without_last_10['cnt']

# Fit ARIMA model
arima_model = ARIMA(y, order=(5, 1, 0))  # Example order, you may need to tune this
arima_result = arima_model.fit()

# Forecast future values
future_steps = 730 # Adjust as needed
forecast = arima_result.get_forecast(steps=future_steps)

# Plotting
plt.figure(figsize=(12, 6))

# Plot actual values
plt.plot(day_Bike_without_last_10.index, day_Bike_without_last_10['cnt'], label='Actual', color='blue')

# Plot predicted values
plt.plot(forecast.predicted_mean.index, forecast.predicted_mean.values, label='ARIMA Prediction', color='red')

# Customize the plot
plt.title('Actual vs ARIMA Prediction')
plt.xlabel('Date')
plt.ylabel('Count')
plt.legend()
plt.grid(True)
plt.show()
